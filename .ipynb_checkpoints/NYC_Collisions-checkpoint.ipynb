# %%
import pandas as pd
import folium
from IPython.display import HTML

# %%
def display(m, height=300):
    """Takes a folium instance and embed HTML."""
    m._build_map()
    srcdoc = m.HTML.replace('"', '&quot;')
    embed = HTML('<iframe srcdoc="{0}" '
                 'style="width: 100%; height: {1}px; '
                 'border: none"></iframe>'.format(srcdoc, height))
    return embed

# %%
accidentData = pd.read_csv('NYPD_Motor_Vehicle_Collisions.csv')

# %%
accidentData.head()
# Out:
#          DATE   TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  10/13/2015  15:20     QUEENS     11419  40.689698 -73.818894
# 1  10/13/2015  15:14      BRONX     10452  40.841771 -73.925487
# 2  10/13/2015  15:11  MANHATTAN     10024  40.790842 -73.974565
# 3  10/13/2015  15:09     QUEENS     11362  40.763880 -73.726715
# 4  10/13/2015  15:08  MANHATTAN     10002  40.715954 -73.986722
#
#                     LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0  (40.6896982, -73.8188938)              NaN               NaN
# 1  (40.8417709, -73.9254873)  WEST 170 STREET    MERRIAM AVENUE
# 2   (40.790842, -73.9745651)   WEST 90 STREET          BROADWAY
# 3  (40.7638802, -73.7267149)              NaN               NaN
# 4  (40.7159536, -73.9867215)     GRAND STREET    CLINTON STREET
#
#                         OFF STREET NAME         ...          \
# 0                     126-07 103 AVENUE         ...
# 1                                   NaN         ...
# ...

# %%
NYC = (40.79, -73.96)

map = folium.Map(location = NYC, zoom_start = 12)

for accident in accidentData[0:100].iterrows():
    map.simple_marker(location = [accident[1]['LONGITUDE'], accident[1]['LATITUDE']], clustered_marker = True)
    
display(map)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
# ...

# %%
type(accidentData['DATE'][1])
# Out:
# str

# %%
accidentData['DATETIME'] = accidentData['DATE'] + ' ' + accidentData['TIME']

accidentData.drop(['DATE', 'TIME'], axis = 1, inplace = True)

accidentData.head()
# Out:
#      BOROUGH  ZIP CODE   LATITUDE  LONGITUDE                   LOCATION  \
# 0     QUEENS     11419  40.689698 -73.818894  (40.6896982, -73.8188938)
# 1      BRONX     10452  40.841771 -73.925487  (40.8417709, -73.9254873)
# 2  MANHATTAN     10024  40.790842 -73.974565   (40.790842, -73.9745651)
# 3     QUEENS     11362  40.763880 -73.726715  (40.7638802, -73.7267149)
# 4  MANHATTAN     10002  40.715954 -73.986722  (40.7159536, -73.9867215)
#
#     ON STREET NAME CROSS STREET NAME                       OFF STREET NAME  \
# 0              NaN               NaN                     126-07 103 AVENUE
# 1  WEST 170 STREET    MERRIAM AVENUE                                   NaN
# 2   WEST 90 STREET          BROADWAY                                   NaN
# 3              NaN               NaN  P/L 254-35 HORACE HARDING EXPRESSWAY
# 4     GRAND STREET    CLINTON STREET                                   NaN
#
#    NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED        ...         \
# ...

# %%
accidentData['DATETIME'] = pd.to_datetime(accidentData['DATETIME'])
type(accidentData['DATETIME'][1])
# Out:
# pandas.tslib.Timestamp

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
accidentData['DATETIME'][1].hour
# Out:
# 15

# %%
accidentData['DATETIME'][1].dayofweek
# Out:
# 1

# %%
x = []
y = []

for dttime in accidentData['DATETIME']:
    x.append(dttime.hour)
    y.append(dttime.dayofweek)

# %%
heatmap, x, y = np.histogram2d(x, y)

# %%
plt.clf()
plt.imshow(heatmap)
plt.show()
